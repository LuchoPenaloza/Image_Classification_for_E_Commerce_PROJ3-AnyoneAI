# %% [markdown]
# # Vehicle Classification
#
# ## Evaluate your model

# %%
import os

from sklearn.metrics import accuracy_score, classification_report

from utils import utils
from models import resnet_50

# %% [markdown]
# ## Experiment settings
#
# Set here the two variables in the following way:
#
# - **CONFIG_YML:** assign the path to the config.yml file used for the experiment you want to evaluate
# - **WEIGHTS:** assign the path to the model weights (.h5 file) you want to evaluate

# %%
# Modify this
CONFIG_YML = "../experiments/exp_017/config.yml"
WEIGHTS = "../experiments/exp_017/model.48-1.1340.h5"

# %%
# (!) Don't touch this cell, will load the config file specified before
config = utils.load_config(CONFIG_YML)
config
# Out:
# {'seed': 123,
#  'data': {'directory': '/home/app/src/data/car_ims_v2/train',
#   'labels': 'inferred',
#   'label_mode': 'categorical',
#   'validation_split': 0.2,
#   'image_size': [224, 224],
#   'batch_size': 32},
#  'model': {'weights': 'imagenet',
#   'input_shape': [224, 224, 3],
#   'classes': 196,
#   'dropout_rate': 0.5,
#   'data_aug_layer': {'random_flip': {'mode': 'horizontal_and_vertical'},
#    'random_rotation': {'factor': 0.5},
#    'random_zoom': {'height_factor': 0.5, 'width_factor': 0.5}}},
#  'compile': {'optimizer': {'adam': {'learning_rate': 0.001, 'epsilon': 0.2}},
#   'loss': 'categorical_crossentropy',
#   'metrics': ['accuracy']},
#  'fit': {'epochs': 50,
#   'callbacks': {'model_checkpoint': {'filepath': '/home/app/src/experiments/exp_017/model.{epoch:02d}-{val_loss:.4f}.h5',
#     'save_best_only': True},
#    'tensor_board': {'log_dir': '/home/app/src/experiments/exp_017/logs'}}}}

# %%
# (!) Don't touch this cell, will use the config file to infer the class names
#     and also to load the corresponding testing dataset.
#     If you get an error, you must review your data/code.

MODEL_CLASSES = utils.get_class_names(config)

if len(MODEL_CLASSES) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your data!"
    )

_dirname, _ = os.path.split(config['data']['directory'])
TEST_FOLDER = os.path.join(_dirname, 'test')

if not os.path.exists(TEST_FOLDER):
    raise ValueError("'test' folder not found!")
    
if len(os.listdir(TEST_FOLDER)) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your testing dataset!"
    )
    
if set(os.listdir(TEST_FOLDER)) != set(MODEL_CLASSES):
    raise ValueError(
        "The name of the subfolders inside your test set "
        "doesn't match with the model classes!"
    )

# %% [markdown]
# ## Load your model
#
# Use `resnet_50.create_model()` and remember to properly setup the model weights!
#
# Assign the model to the variable `cnn_model`.

# %%
# Complete this
# TODO
cnn_model = resnet_50.create_model(WEIGHTS)

# It should print your model correctly
print(cnn_model.summary())
# Out:
# 2022-06-25 19:11:03.469762: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-25 19:11:03.479131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-25 19:11:03.479941: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-25 19:11:03.481369: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-25 19:11:03.481848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-25 19:11:03.482635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-25 19:11:03.483361: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-25 19:11:04.117358: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-25 19:11:04.118207: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-25 19:11:04.119010: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-25 19:11:04.119736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10100 MB memory:  -> device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 196)               401604
#
# =================================================================
# Total params: 23,989,316
# Trainable params: 23,936,196
# Non-trainable params: 53,120
# _________________________________________________________________
# None

# %% [markdown]
# ## Get predictions from testing dataset

# %%
# (!) Don't touch this cell, will use the loaded model and
#     the function utils.predict_from_folder() to get 
#     model predictions and the corresponding true labels
#     so we can measure the accuracy

predictions, labels = utils.predict_from_folder(
    folder=TEST_FOLDER, 
    model=cnn_model, 
    input_size=config["data"]["image_size"], 
    class_names=MODEL_CLASSES,
)

if len(predictions) != len(labels):
    raise ValueError(
        "The lenght of predictions and labels lists doesn't match!"
    )

if not isinstance(predictions[0], str):
    raise ValueError(
        "Model predictions should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )

if not isinstance(labels[0], str):
    raise ValueError(
        "Ground true labels should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )
# Out:
# 2022-06-25 19:11:30.275898: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 2022-06-25 19:11:30.567553: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-25 19:11:30.568212: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-25 19:11:30.568332: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-06-25 19:11:30.569088: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-25 19:11:30.569264: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.

# %%
# (!) Don't touch this cell

print(classification_report(y_true=labels, y_pred=predictions))
# Out:
#                                                         precision    recall  f1-score   support
#
#                             AM General Hummer SUV 2000       0.66      0.80      0.72        44
#                              Acura Integra Type R 2001       0.67      0.68      0.67        44
#                                    Acura RL Sedan 2012       0.50      0.44      0.47        32
#                                    Acura TL Sedan 2012       0.82      0.77      0.80        43
#                                   Acura TL Type-S 2008       0.89      0.74      0.81        42
#                                   Acura TSX Sedan 2012       0.94      0.38      0.54        40
#                               Acura ZDX Hatchback 2012       0.69      0.64      0.67        39
#               Aston Martin V8 Vantage Convertible 2012       0.36      0.58      0.44        45
#                     Aston Martin V8 Vantage Coupe 2012       0.62      0.12      0.20        41
#                   Aston Martin Virage Convertible 2012       0.49      0.64      0.55        33
#                         Aston Martin Virage Coupe 2012       0.77      0.89      0.83        38
#                                    Audi 100 Sedan 1994       0.50      0.38      0.43        40
#                                    Audi 100 Wagon 1994       0.60      0.21      0.32        42
#                                     Audi A5 Coupe 2012       0.45      0.76      0.56        41
#                                     Audi R8 Coupe 2012       0.83      0.58      0.68        43
#                             Audi RS 4 Convertible 2008       0.47      0.64      0.54        36
#                                     Audi S4 Sedan 2007       0.72      0.58      0.64        45
#                                     Audi S4 Sedan 2012       0.40      0.21      0.27        39
#                               Audi S5 Convertible 2012       0.32      0.26      0.29        42
#                                     Audi S5 Coupe 2012       0.38      0.31      0.34        42
#                                     Audi S6 Sedan 2011       0.74      0.57      0.64        46
#                                 Audi TT Hatchback 2011       0.45      0.35      0.39        40
#                                  Audi TT RS Coupe 2012       0.59      0.74      0.66        39
#                                    Audi TTS Coupe 2012       0.50      0.31      0.38        42
#                                     Audi V8 Sedan 1994       0.50      0.51      0.51        43
#                          BMW 1 Series Convertible 2012       0.55      0.31      0.40        35
#                                BMW 1 Series Coupe 2012       0.79      0.46      0.58        41
#                                BMW 3 Series Sedan 2012       0.70      0.45      0.55        42
#                                 Mazda Tribute SUV 2011       0.84      0.58      0.69        36
#                             McLaren MP4-12C Coupe 2012       0.88      0.82      0.85        44
#               Mercedes-Benz 300-Class Convertible 1993       0.52      0.85      0.65        48
#                       Mercedes-Benz C-Class Sedan 2012       0.79      0.73      0.76        45
#                       Mercedes-Benz E-Class Sedan 2012       0.24      0.93      0.38        43
#                       Mercedes-Benz S-Class Sedan 2012       0.82      0.32      0.46        44
#                      Mercedes-Benz SL-Class Coupe 2009       0.78      0.58      0.67        36
#                        Mercedes-Benz Sprinter Van 2012       0.69      0.93      0.79        41
#                           Mitsubishi Lancer Sedan 2012       0.79      0.55      0.65        47
#                                Nissan 240SX Coupe 1998       0.74      0.61      0.67        46
#                             Nissan Juke Hatchback 2012       0.68      0.91      0.78        44
#                             Nissan Leaf Hatchback 2012       0.79      0.90      0.84        42
#                           Nissan NV Passenger Van 2012       0.70      0.84      0.76        38
#                               Plymouth Neon Coupe 1999       0.76      0.80      0.78        44
#                            Porsche Panamera Sedan 2012       0.67      0.79      0.72        43
#                         Ram C-V Cargo Van Minivan 2012       0.86      0.46      0.60        41
#                           Rolls-Royce Ghost Sedan 2012       0.41      0.61      0.49        38
#    Rolls-Royce Phantom Drophead Coupe Convertible 2012       0.36      0.67      0.47        30
#                         Rolls-Royce Phantom Sedan 2012       0.57      0.48      0.52        44
#                                Scion xD Hatchback 2012       0.61      0.76      0.67        41
#                             Spyker C8 Convertible 2009       0.74      0.71      0.73        45
#                                   Spyker C8 Coupe 2009       0.85      0.55      0.67        42
#                                Suzuki Aerio Sedan 2007       0.61      0.50      0.55        38
#                              Suzuki Kizashi Sedan 2012       0.84      0.67      0.75        46
#                              Suzuki SX4 Hatchback 2012       0.46      0.86      0.60        42
#                                  Suzuki SX4 Sedan 2012       0.65      0.33      0.43        40
#                               Tesla Model S Sedan 2012       0.86      0.82      0.84        38
#                                Toyota 4Runner SUV 2012       0.91      0.50      0.65        40
#                                Toyota Camry Sedan 2012       0.46      0.65      0.54        43
#                              Toyota Corolla Sedan 2012       0.60      0.42      0.49        43
#                                Toyota Sequoia SUV 2012       1.00      0.76      0.87        38
#                       Volkswagen Beetle Hatchback 2012       0.61      0.90      0.73        42
#                         Volkswagen Golf Hatchback 1991       0.49      0.96      0.65        46
#                         Volkswagen Golf Hatchback 2012       0.95      0.44      0.60        43
#                                   Volvo 240 Sedan 1993       0.66      0.89      0.75        45
#                               Volvo C30 Hatchback 2012       0.91      0.71      0.79        41
#                                    Volvo XC90 SUV 2007       0.81      0.51      0.63        43
#                          smart fortwo Convertible 2012       0.77      0.60      0.68        40
#
#                                               accuracy                           0.64      8041
#                                              macro avg       0.71      0.64      0.64      8041
#                                           weighted avg       0.70      0.64      0.64      8041

# %%
# (!) Don't touch this cell

acc = accuracy_score(y_true=labels, y_pred=predictions)

print(f"Your model accuracy is {acc:.4f}!")

if acc < .3:
    raise ValueError("Your model accuracy is too low :(\nYou can do it better! :)")
# Out:
# Your model accuracy is 0.6430!
